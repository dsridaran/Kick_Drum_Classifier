# %% [markdown]
# Before running code, set working environment to **src** folder.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/FIFA/Cloned Repository/test/Kick_Drum_Classifier/src
from call_model import predict_sounds
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/.shortcut-targets-by-id/1oF2xDqmAbEcHI3KqIc48ey_Q88_tnlPx/FIFA/Cloned Repository/test/Kick_Drum_Classifier/src

# %% [markdown]
# # Calling Classification Models
#
# This notebook provides the interface to run pre-trained kick and drum classification models on new samples. Inference is performed by calling the **predict_sounds()** function, which has parameters:
#
# *   **files** (list): List of audio files on which to run inference.
# *   **model** (str): Filepath to pre-trained model.

# %%
predict_sounds(
    files = ['../data/raw/drum/Drum_140.wav', '../data/raw/kick/SFC_CFC_Kick_56.wav'],
    model = '../models/base.h5'
)
# Out:
# [{'file': '../data/raw/drum/Drum_140.wav',
#   'predicted_class': 'Drum',
#   'confidence': 0.96979123},
#  {'file': '../data/raw/kick/SFC_CFC_Kick_56.wav',
#   'predicted_class': 'Kick',
#   'confidence': 0.87651247}]
